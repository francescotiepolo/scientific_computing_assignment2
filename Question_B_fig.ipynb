# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from src.Question_B_funcs import monte_carlo_dla

save_folder = 'fig'
os.makedirs(save_folder, exist_ok=True)
dla_grid_mc = monte_carlo_dla(grid_size=(100, 100), num_walkers=500 ,steps=50000)

plt.figure(figsize=(10, 10))
plt.imshow(dla_grid_mc, origin="upper", cmap="plasma")
plt.title("Monte Carlo DLA Growth")
plt.axis("off")
save_path = os.path.join(save_folder, f'Question B.png')
plt.savefig(save_path, dpi=300)
plt.show()
