# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from src.Question_B_funcs import monte_carlo_dla

np.random.seed(10)
save_folder = 'fig'
os.makedirs(save_folder, exist_ok=True)
dla_grid_mc = monte_carlo_dla(grid_size=(100, 100),steps=10000000)

plt.figure(figsize=(10, 10))
plt.imshow(dla_grid_mc, origin="upper", cmap="plasma")
plt.title("Monte Carlo DLA Growth", fontsize = 18, fontweight="bold")
plt.axis("off")
save_path = os.path.join(save_folder, f'Question B.png')
plt.savefig(save_path, dpi=300)
plt.show()

# takes a lot of iterations since only one walker moves at any given moment, take a random path and have to find the cluster 
# before sticking, early on, there’s only a single seed at the bottom, so walkers take a long time to attach.
# Furthermore, If a walker reaches the top or bottom, it's removed and replaced with a new one. 
# This means some walkers never reach the cluster at all and are wasted.
